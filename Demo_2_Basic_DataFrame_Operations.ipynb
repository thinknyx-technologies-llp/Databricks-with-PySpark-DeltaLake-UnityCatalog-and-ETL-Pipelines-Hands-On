# %%
spark

# %%
movies_df = spark.read.csv("dbfs:/FileStore/tables/movies_dataset.csv", header=True, inferSchema=True)
movies_df.show(5)

# %%
movies_df = spark.read.csv("/Volumes/workspace/default/thinknyx_vol/movies_dataset.csv", header=True, inferSchema=True)
movies_df.show(5)

# %%
movies_df_2 = spark.table("workspace.default.movies_dataset")
movies_df_2.show(5)

# %%
movies_df.display()

# %%
movies_df.printSchema()

# %%
movies_df.select("title", "genre_ids", "adult").show(10)

# %%
movies_df.filter(movies_df.original_language == "hi").display()

# %%
movies_df.groupBy("original_language").count().display()
