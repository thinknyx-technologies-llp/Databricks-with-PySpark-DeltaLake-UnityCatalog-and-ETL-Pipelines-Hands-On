# %% [markdown]
# ## Movies Dataset Analysis
# This section explores ratings and genres using Spark.

# %%
# %fs ls /FileStore/tables/

# %%
# %run "/Workspace/Users/howdeessh@gmail.com/test1"

# %%
# %scala
spark.range(1, 6).show()

# %%
# %r

# %%
# %sh
ls

# %%
# %pip install pandas

# %%
# %env NYX=training
